# %%
import pandas as pd
from openpyxl import load_workbook

# %%
#vehicle settle para Online runs 

#Engaged Analysis para Curve runs

online_csv_path = '/Users/josedejesuspena/Documents/files to test with AG report/36 runs/KringleZIP 2026-06-30 17-21-07/Auto-guidance - Summary/Vehicle Online Results Metrics - VehicleOnlineAnalysis.csv'
curve_csv_path  = '/Users/josedejesuspena/Documents/files to test with AG report/36 runs/KringleZIP 2026-06-30 17-21-07/Auto-guidance - Summary/Results Metrics - EngagedAnalysis.csv'

# %%
df_OnlineAnalysis_csv = pd.read_csv(online_csv_path)  
df_EngagedAnalysis_csv = pd.read_csv(curve_csv_path)

# %%
df_OnlineAnalysis_csv['Data Source']
# Out:
# 0      Run 1 - Magnum_380_run_1_1.25mph_2
# 1      Run 2 - Magnum_380_run_1_1.25mph_3
# 2         Run 3 - Magnum_380_run_2_3mph_1
# 3         Run 4 - Magnum_380_run_2_3mph_2
# 4         Run 5 - Magnum_380_run_2_3mph_3
# 5       Run 6 - Magnum_380_run_3_6.2mph_1
# 6       Run 7 - Magnum_380_run_3_6.2mph_2
# 7       Run 8 - Magnum_380_run_3_6.2mph_3
# 8       Run 9 - Magnum_380_run_4_9.2mph_1
# 9      Run 10 - Magnum_380_run_4_9.2mph_2
# 10     Run 11 - Magnum_380_run_4_9.2mph_3
# 11    Run 12 - Magnum_380_run_5_12.4mph_1
# 12    Run 13 - Magnum_380_run_5_12.4mph_2
# 13    Run 14 - Magnum_380_run_5_12.4mph_3
# 14       Run 15 - Magnum_380_run_6_5mph_2
# 15       Run 16 - Magnum_380_run_6_5mph_3
# 16       Run 17 - Magnum_380_run_7_5mph_3
# 17       Run 18 - Magnum_380_run_8_8mph_1
# 18       Run 19 - Magnum_380_run_8_8mph_3
# 19     Run 20 - Magnum_380_run_9_3.6mph_1
# 20      Run 21 - Magnum_380_run_10_5mph_1
# 21      Run 22 - Magnum_380_run_11_8mph_1
# 22      Run 23 - Magnum_380_run_11_8mph_2
# 23    Run 24 - Magnum_380_run_12_3.6mph_1
# 24    Run 25 - Magnum_380_run_13_3.6mph_1
# 25      Run 26 - Magnum_380_run_14_5mph_1
# 26      Run 27 - Magnum_380_run_15_5mph_1
# 27      Run 28 - Magnum_380_run_16_8mph_1
# 28      Run 29 - Magnum_380_run_17_8mph_1
# 29    Run 30 - Magnum_380_run_18_3.6mph_1
# 30    Run 31 - Magnum_380_run_19_3.6mph_1
# 31      Run 32 - Magnum_380_run_20_5mph_1
# 32      Run 33 - Magnum_380_run_21_5mph_1
# Name: Data Source, dtype: str

# %%
# Parameters
column = "Data Source"      # Column to modify
text = "_straight"         # Text to append
row_start = 0            # First row (0-based index)
row_end = 13              # Last row (inclusive)

# Append the text to the specified rows
df_OnlineAnalysis_csv.loc[row_start:row_end, column] = (
    df_OnlineAnalysis_csv.loc[row_start:row_end, column]
      .fillna("")
      .astype(str)
      + text
)

# Save the updated CSV
df_OnlineAnalysis_csv.to_csv("online_updated.csv", index=False)

# %%
df_EngagedAnalysis_csv['Data Source']
# Out:
# 0      Run 1 - Magnum_380_run_1_1.25mph_2
# 1      Run 2 - Magnum_380_run_1_1.25mph_3
# 2         Run 3 - Magnum_380_run_2_3mph_1
# 3         Run 4 - Magnum_380_run_2_3mph_2
# 4         Run 5 - Magnum_380_run_2_3mph_3
# 5       Run 6 - Magnum_380_run_3_6.2mph_1
# 6       Run 7 - Magnum_380_run_3_6.2mph_2
# 7       Run 8 - Magnum_380_run_3_6.2mph_3
# 8       Run 9 - Magnum_380_run_4_9.2mph_1
# 9      Run 10 - Magnum_380_run_4_9.2mph_2
# 10     Run 11 - Magnum_380_run_4_9.2mph_3
# 11    Run 12 - Magnum_380_run_5_12.4mph_1
# 12    Run 13 - Magnum_380_run_5_12.4mph_2
# 13    Run 14 - Magnum_380_run_5_12.4mph_3
# 14       Run 15 - Magnum_380_run_6_5mph_1
# 15       Run 16 - Magnum_380_run_6_5mph_2
# 16       Run 17 - Magnum_380_run_6_5mph_3
# 17       Run 18 - Magnum_380_run_7_5mph_1
# 18       Run 19 - Magnum_380_run_7_5mph_2
# 19       Run 20 - Magnum_380_run_7_5mph_3
# 20       Run 21 - Magnum_380_run_8_8mph_1
# 21       Run 22 - Magnum_380_run_8_8mph_2
# 22       Run 23 - Magnum_380_run_8_8mph_3
# 23     Run 24 - Magnum_380_run_9_3.6mph_1
# 24      Run 25 - Magnum_380_run_10_5mph_1
# 25      Run 26 - Magnum_380_run_11_8mph_1
# 26      Run 27 - Magnum_380_run_11_8mph_2
# 27    Run 28 - Magnum_380_run_12_3.6mph_1
# 28    Run 29 - Magnum_380_run_13_3.6mph_1
# 29      Run 30 - Magnum_380_run_14_5mph_1
# 30      Run 31 - Magnum_380_run_15_5mph_1
# 31      Run 32 - Magnum_380_run_16_8mph_1
# 32      Run 33 - Magnum_380_run_17_8mph_1
# 33    Run 34 - Magnum_380_run_18_3.6mph_1
# 34    Run 35 - Magnum_380_run_19_3.6mph_1
# 35      Run 36 - Magnum_380_run_20_5mph_1
# 36      Run 37 - Magnum_380_run_21_5mph_1
# Name: Data Source, dtype: str

# %%
# Parameters
column = "Data Source"      # Column to modify
text = "_curve"         # Text to append
row_start = 14            # First row (0-based index)
row_end = 22              # Last row (inclusive)

# Append the text to the specified rows
df_EngagedAnalysis_csv.loc[row_start:row_end, column] = (
    df_EngagedAnalysis_csv.loc[row_start:row_end, column]
      .fillna("")
      .astype(str)
      + text
)

# Save the updated CSV
df_EngagedAnalysis_csv.to_csv("curve_updated.csv", index=False)
